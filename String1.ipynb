# %%
institute = "Edukron"
focus_area = " Data Science "
tech_stack = "Azure DevOps and Python"
course_slogan = "Learn Data Engineering with Real-Time Projects"

# %%
print ("My "+"institute is "+institute)
# Out:
# My institute is Edukron

# %%
print (f"1. Focusarea: {focus_area*3
                        }"
       )
# Out:
# 1. Focusarea:  Data Science  Data Science  Data Science

# %%
print(len(course_slogan))
# Out:
# 46

# %%
print(institute[5 ])
print(institute[-5])
# Out:
# o
# u

# %%
print(str.upper(institute))
abc=str.upper(institute)
print(str.lower(abc))
# Out:
# EDUKRON
# edukron

# %%
print(abc[0:4          ])
# Out:
# EDUK
